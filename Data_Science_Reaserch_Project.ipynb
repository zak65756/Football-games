# %% [markdown]
# <a href="https://colab.research.google.com/github/zak65756/Football-games/blob/main/Data_Science_Reaserch_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv('/content/games.csv')
df.head()
# Out:
#            game_id  season game_type  week     gameday weekday gametime  \
# 0  1999_01_MIN_ATL    1999       REG     1  1999-09-12  Sunday      NaN
# 1   1999_01_KC_CHI    1999       REG     1  1999-09-12  Sunday      NaN
# 2  1999_01_PIT_CLE    1999       REG     1  1999-09-12  Sunday      NaN
# 3   1999_01_OAK_GB    1999       REG     1  1999-09-12  Sunday      NaN
# 4  1999_01_BUF_IND    1999       REG     1  1999-09-12  Sunday      NaN
#
#   away_team  away_score home_team  ...  wind  away_qb_id  home_qb_id  \
# 0       MIN        17.0       ATL  ...   NaN  00-0003761  00-0002876
# 1        KC        17.0       CHI  ...  12.0  00-0006300  00-0010560
# 2       PIT        43.0       CLE  ...  12.0  00-0015700  00-0004230
# 3       OAK        24.0        GB  ...  10.0  00-0005741  00-0005106
# 4       BUF        14.0       IND  ...   NaN  00-0005363  00-0010346
#
#          away_qb_name    home_qb_name          away_coach    home_coach  \
# ...

# %%
import os
print(os.listdir('/content/'))
# Out:
# ['.config', 'drive', 'games.csv', 'sample_data']

# %%
df.describe()
# Out:
#             season         week   away_score   home_score       result  \
# count  7263.000000  7263.000000  6991.000000  6991.000000  6991.000000
# mean   2012.153518     9.581716    20.914604    23.271778     2.357174
# std       7.806915     5.329248    10.040376    10.312372    14.609486
# min    1999.000000     1.000000     0.000000     0.000000   -49.000000
# 25%    2005.000000     5.000000    14.000000    16.000000    -7.000000
# 50%    2012.000000    10.000000    20.000000    23.000000     3.000000
# 75%    2019.000000    14.000000    27.000000    30.000000    11.000000
# max    2025.000000    22.000000    59.000000    70.000000    59.000000
#
#              total     overtime   old_game_id          gsis           pff  \
# count  6991.000000  6991.000000  7.263000e+03  6.991000e+03   4292.000000
# mean     44.186382     0.061079  2.012328e+09  3.294691e+05   6197.638164
# std      14.172906     0.239491  7.817014e+06  2.390869e+07   6075.412083
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7263 entries, 0 to 7262
# Data columns (total 46 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   game_id           7263 non-null   object
#  1   season            7263 non-null   int64
#  2   game_type         7263 non-null   object
#  3   week              7263 non-null   int64
#  4   gameday           7263 non-null   object
#  5   weekday           7263 non-null   object
#  6   gametime          7004 non-null   object
#  7   away_team         7263 non-null   object
#  8   away_score        6991 non-null   float64
#  9   home_team         7263 non-null   object
#  10  home_score        6991 non-null   float64
#  11  location          7263 non-null   object
#  12  result            6991 non-null   float64
#  13  total             6991 non-null   float64
#  14  overtime          6991 non-null   float64
#  15  old_game_id       7263 non-null   int64
# ...

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of       game_id  season  game_type   week  gameday  weekday  gametime  \
# 0       False   False      False  False    False    False      True
# 1       False   False      False  False    False    False      True
# 2       False   False      False  False    False    False      True
# 3       False   False      False  False    False    False      True
# 4       False   False      False  False    False    False      True
# ...       ...     ...        ...    ...      ...      ...       ...
# 7258    False   False      False  False    False    False     False
# 7259    False   False      False  False    False    False     False
# 7260    False   False      False  False    False    False     False
# 7261    False   False      False  False    False    False     False
# 7262    False   False      False  False    False    False     False
#
#       away_team  away_score  home_team  ...   wind  away_qb_id  home_qb_id  \
# ...

# %%
df.iloc()

# %%
df.shape
# Out:
# (7263, 46)

# %%
df.columns
# Out:
# Index(['game_id', 'season', 'game_type', 'week', 'gameday', 'weekday',
#        'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
#        'location', 'result', 'total', 'overtime', 'old_game_id', 'gsis',
#        'nfl_detail_id', 'pfr', 'pff', 'espn', 'ftn', 'away_rest', 'home_rest',
#        'away_moneyline', 'home_moneyline', 'spread_line', 'away_spread_odds',
#        'home_spread_odds', 'total_line', 'under_odds', 'over_odds', 'div_game',
#        'roof', 'surface', 'temp', 'wind', 'away_qb_id', 'home_qb_id',
#        'away_qb_name', 'home_qb_name', 'away_coach', 'home_coach', 'referee',
#        'stadium_id', 'stadium'],
#       dtype='object')

# %%
df.fillna(0)
# Out:
#               game_id  season game_type  week     gameday weekday gametime  \
# 0     1999_01_MIN_ATL    1999       REG     1  1999-09-12  Sunday        0
# 1      1999_01_KC_CHI    1999       REG     1  1999-09-12  Sunday        0
# 2     1999_01_PIT_CLE    1999       REG     1  1999-09-12  Sunday        0
# 3      1999_01_OAK_GB    1999       REG     1  1999-09-12  Sunday        0
# 4     1999_01_BUF_IND    1999       REG     1  1999-09-12  Sunday        0
# ...               ...     ...       ...   ...         ...     ...      ...
# 7258  2025_18_DAL_NYG    2025       REG    18  2026-01-04  Sunday    13:00
# 7259  2025_18_WAS_PHI    2025       REG    18  2026-01-04  Sunday    13:00
# 7260  2025_18_BAL_PIT    2025       REG    18  2026-01-04  Sunday    13:00
# 7261   2025_18_SEA_SF    2025       REG    18  2026-01-04  Sunday    13:00
# 7262   2025_18_CAR_TB    2025       REG    18  2026-01-04  Sunday    13:00
#
# ...

# %%
df.value_counts()
# Out:
# game_id          season  game_type  week  gameday     weekday   gametime  away_team  away_score  home_team  home_score  location  result  total  overtime  old_game_id  gsis     nfl_detail_id                         pfr           pff      espn         ftn     away_rest  home_rest  away_moneyline  home_moneyline  spread_line  away_spread_odds  home_spread_odds  total_line  under_odds  over_odds  div_game  roof      surface    temp  wind  away_qb_id  home_qb_id  away_qb_name        home_qb_name     away_coach       home_coach      referee        stadium_id  stadium
# ...

# %%
df.dropna()
# Out:
#               game_id  season game_type  week     gameday   weekday gametime  \
# 5852   2021_01_DAL_TB    2021       REG     1  2021-09-09  Thursday    20:20
# 5854  2021_01_PIT_BUF    2021       REG     1  2021-09-12    Sunday    13:00
# 5855  2021_01_NYJ_CAR    2021       REG     1  2021-09-12    Sunday    13:00
# 5856  2021_01_MIN_CIN    2021       REG     1  2021-09-12    Sunday    13:00
# 5860  2021_01_ARI_TEN    2021       REG     1  2021-09-12    Sunday    13:00
# ...               ...     ...       ...   ...         ...       ...      ...
# 6114  2021_18_IND_JAX    2021       REG    18  2022-01-09    Sunday    13:00
# 6116  2021_18_WAS_NYG    2021       REG    18  2022-01-09    Sunday    13:00
# 6119  2021_18_NYJ_BUF    2021       REG    18  2022-01-09    Sunday    16:25
# 6121   2021_18_NE_MIA    2021       REG    18  2022-01-09    Sunday    16:25
# 6122   2021_18_CAR_TB    2021       REG    18  2022-01-09    Sunday    16:25
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['home_score'], kde=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='game_type', data=df)
plt.show()

# %%
plt.bar(df['home_score'], df['away_score'])
plt.xlabel('Home Score')
plt.ylabel('Away Score')
plt.show()

# %% [markdown]
# Question: Do NFL teams score more when playing at home games?

# %%
# Total score for each game
df['total_score'] = df['home_score'] + df['away_score']
df['home_win'] = df['home_score'] > df['away_score']

# %%
# Calculate average points scored at home
home_avg = df['home_score'].mean()

# Calculate average points scored away
away_avg = df['away_score'].mean()

# Print the results
print("Average Home Score:", round(home_avg, 2))
print("Average Away Score:", round(away_avg, 2))
# Out:
# Average Home Score: 23.27
# Average Away Score: 20.91

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def get_home_result(row):
    if row['home_score'] > row['away_score']:
        return 'Win'
    elif row['home_score'] < row['away_score']:
        return 'Loss'
    else:
        return 'Tie'

df['home_result'] = df.apply(get_home_result, axis=1)

# %%
home_result_counts = df['home_result'].value_counts()
print(home_result_counts)
# Out:
# home_result
# Win     3945
# Loss    3032
# Tie      286
# Name: count, dtype: int64

# %%
print(df[['home_team', 'away_team', 'home_score', 'away_score', 'home_result']].head(130))
# Out:
#     home_team away_team  home_score  away_score home_result
# 0         ATL       MIN        14.0        17.0        Loss
# 1         CHI        KC        20.0        17.0         Win
# 2         CLE       PIT         0.0        43.0        Loss
# 3          GB       OAK        28.0        24.0         Win
# 4         IND       BUF        31.0        14.0         Win
# ..        ...       ...         ...         ...         ...
# 125        SF       PIT         6.0        27.0        Loss
# 126       WAS       BUF        17.0        34.0        Loss
# 127       MIN       DAL        27.0        17.0         Win
# 128       ARI       DET        23.0        19.0         Win
# 129       BUF       MIA        23.0         3.0         Win
#
# [130 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

df['home_result'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Home Team Results')
plt.ylabel('')
plt.show()

# %%
df['gameday'] = pd.to_datetime(df['gameday'])  # convert to date
df['week'] = pd.to_numeric(df['week'], errors='coerce')  # convert to int

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7263 entries, 0 to 7262
# Data columns (total 49 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   game_id           7263 non-null   object
#  1   season            7263 non-null   int64
#  2   game_type         7263 non-null   object
#  3   week              7263 non-null   int64
#  4   gameday           7263 non-null   datetime64[ns]
#  5   weekday           7263 non-null   object
#  6   gametime          7004 non-null   object
#  7   away_team         7263 non-null   object
#  8   away_score        6991 non-null   float64
#  9   home_team         7263 non-null   object
#  10  home_score        6991 non-null   float64
#  11  location          7263 non-null   object
#  12  result            6991 non-null   float64
#  13  total             6991 non-null   float64
#  14  overtime          6991 non-null   float64
#  15  old_game_id       7263 non-null   int64
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df['wind'].fillna(0, inplace=True)  # if missing = no wind
df['gametime'].fillna('00:00', inplace=True)  # placeholder
# Out:
# /tmp/ipython-input-28-374880812.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['wind'].fillna(0, inplace=True)  # if missing = no wind
# /tmp/ipython-input-28-374880812.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.columns
# Out:
# Index(['game_id', 'season', 'game_type', 'week', 'gameday', 'weekday',
#        'gametime', 'away_team', 'away_score', 'home_team', 'home_score',
#        'location', 'result', 'total', 'overtime', 'old_game_id', 'gsis',
#        'nfl_detail_id', 'pfr', 'pff', 'espn', 'ftn', 'away_rest', 'home_rest',
#        'away_moneyline', 'home_moneyline', 'spread_line', 'away_spread_odds',
#        'home_spread_odds', 'total_line', 'under_odds', 'over_odds', 'div_game',
#        'roof', 'surface', 'temp', 'wind', 'away_qb_id', 'home_qb_id',
#        'away_qb_name', 'home_qb_name', 'away_coach', 'home_coach', 'referee',
#        'stadium_id', 'stadium', 'total_score', 'home_win', 'home_result'],
#       dtype='object')

# %%
df['home_score'].unique
plt.hist(df['home_score'], bins=20)
plt.xlabel('Home Score')
plt.ylabel('Frequency')
plt.show()

# %%
 plt.scatter(df['home_score'], df['away_score'])
plt.xlabel('Home Score')
plt.ylabel('Away Score')
plt.show()

# %%
df2 = df.groupby('home_team')['home_score'].mean().reset_index()
df2
# Out:
#    home_team  home_score
# 0        ARI   21.869767
# 1        ATL   24.055300
# 2        BAL   24.895455
# 3        BUF   23.141553
# 4        CAR   21.162037
# 5        CHI   21.444954
# 6        CIN   22.555556
# 7        CLE   18.033333
# 8        DAL   25.576037
# 9        DEN   23.909502
# 10       DET   23.605634
# 11        GB   26.292035
# 12       HOU   22.252577
# 13       IND   25.470852
# 14       JAX   20.565421
# 15        KC   24.869565
# 16        LA   23.737500
# 17       LAC   23.818182
# 18        LV   23.619048
# 19       MIA   21.680751
# 20       MIN   24.631336
# 21        NE   26.238494
# 22        NO   26.208145
# 23       NYG   21.111111
# 24       NYJ   20.687204
# 25       OAK   22.086705
# 26       PHI   24.758621
# 27       PIT   24.511111
# 28        SD   24.644295
# 29       SEA   24.848214
# 30        SF   23.049774
# 31       STL   24.141844
# 32        TB   21.972851
# 33       TEN   22.658986
# 34       WAS   20.542056

# %%
df2 = df.groupby('away_team')['away_score'].mean().reset_index()
df2
# Out:
#    away_team  away_score
# 0        ARI   19.339535
# 1        ATL   20.368664
# 2        BAL   21.176724
# 3        BUF   20.465116
# 4        CAR   20.767123
# 5        CHI   18.715640
# 6        CIN   19.894009
# 7        CLE   17.995327
# 8        DAL   20.623853
# 9        DEN   21.283721
# 10       DET   19.744186
# 11        GB   24.309735
# 12       HOU   19.208333
# 13       IND   23.453333
# 14       JAX   19.328704
# 15        KC   23.374429
# 16        LA   23.864198
# 17       LAC   23.400000
# 18        LV   20.255814
# 19       MIA   19.250000
# 20       MIN   21.404545
# 21        NE   24.892377
# 22        NO   23.821101
# 23       NYG   20.720721
# 24       NYJ   18.081448
# 25       OAK   18.643275
# 26       PHI   23.538117
# 27       PIT   20.816964
# 28        SD   22.657718
# 29       SEA   21.373333
# 30        SF   20.824324
# 31       STL   18.787234
# 32        TB   21.050459
# 33       TEN   20.262443
# 34       WAS   19.884793

# %%
df2 = df.groupby('home_team')['home_score'].mean().reset_index()
plt.bar(df2['home_team'], df2['home_score'])
plt.xlabel('Home Team')
plt.ylabel('Average Home Score')
plt.xticks(rotation=90)
plt.show()

# %%
df2 = df.groupby('away_team')['away_score'].mean().reset_index()
plt.bar(df2['away_team'], df2['away_score'])
plt.xlabel('away Team')
plt.ylabel('Average away Score')
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#            game_id  season game_type  week    gameday weekday gametime  \
# 0  1999_01_MIN_ATL    1999       REG     1 1999-09-12  Sunday    00:00
# 1   1999_01_KC_CHI    1999       REG     1 1999-09-12  Sunday    00:00
# 2  1999_01_PIT_CLE    1999       REG     1 1999-09-12  Sunday    00:00
# 3   1999_01_OAK_GB    1999       REG     1 1999-09-12  Sunday    00:00
# 4  1999_01_BUF_IND    1999       REG     1 1999-09-12  Sunday    00:00
#
#   away_team  away_score home_team  ...        away_qb_name    home_qb_name  \
# 0       MIN        17.0       ATL  ...  Randall Cunningham  Chris Chandler
# 1        KC        17.0       CHI  ...         Elvis Grbac  Shane Matthews
# 2       PIT        43.0       CLE  ...     Kordell Stewart       Ty Detmer
# 3       OAK        24.0        GB  ...         Rich Gannon     Brett Favre
# 4       BUF        14.0       IND  ...         Doug Flutie  Peyton Manning
#
#            away_coach    home_coach        referee  stadium_id  \
# ...

# %%
df2 = df.groupby('game_type')['home_score']
